# %% [markdown]
# ## Subnetwork consensus annotations from CANOPUS and library ID's
#
# ConCISE takes your library identified compounds and putative annotations exported from CANOPUS in SIRIUS 4 and find consensus annotations at a network level.

# %% [markdown]
# #### Drag and drop your input files in the jupyter lab environment (left panel)
#
# #### Replace the filenames and library ID number in the function below. If you would like to specify other thresholds for each level replace them as needed. They are ordered as superclass, class, subclass in the function and will default to 50%, 70%, 70%. The final argument tells concise if you want to use NPClassifier; the default is for ConCISE to use ClassyFire (False), but if you change the final argument to 'True' then ConCISE will use NPClassifier.
#
# #### ***Update:*** You can now manually supply your own spectral library match file with curated ontologies. To do so, put the name of the file in place of the libraryID in the command below.
# The format looks like:
# `python3 conciseCLI.py libraryID canopus_summary.tsv subnetworkFile.tsv 50 70 70 False`

# %%
# !python3 conciseCLI.py 16616afa8edd490ea7e50cc316a20222 notebookTestFiles/canopus_summary.tsv notebookTestFiles/Node_info.tsv 50 70 70 False

# %% [markdown]
# #### Run the above cell.

# %% [markdown]
# #### Download your putative annotation file (left panel and right click to download).
