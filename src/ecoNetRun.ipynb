# %% [markdown]
# ## FBMN - Filter MGF from MZmine
#
# EcoNet takes your library identified compounds and putative annotations exported from CANOPUS in SIRIUS 4 and find consensus annotations at a network level.

# %% [markdown]
# #### Drag and drop your input files in the jupyter lab environment (left panel)
#
# #### Replace the filenames and library ID number in the function below.
# The format looks like:
# `python3 workflowEcoNet.py 16616afa8edd490ea7e50cc316a20222 notebookTestFiles/canopus_summary.tsv notebookTestFiles/Node_info.tsv`

# %%
# !python3 workflowEcoNet.py 16616afa8edd490ea7e50cc316a20222 notebookTestFiles/canopus_summary.tsv notebookTestFiles/Node_info.tsv

# %% [markdown]
# #### Run the cell.

# %% [markdown]
# #### Download your putative annotation file (left panel and right click to download).
